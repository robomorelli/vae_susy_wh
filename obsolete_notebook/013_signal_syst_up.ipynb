# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import uproot
import scipy.stats as st
from scipy.special import beta
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import random
import os
import shutil
from pathlib import Path
from subprocess import check_output

from config import *

random.seed(30)

data_folder = root_folder + 'user.eschanet.allTrees_v2_0_2_signal_1Lbb_skim.root'

# %%
root = uproot.open(data_folder)

# %%
signal_id = []
count = 0

for n in root.keys():
        if 'nosys' not in str(n).lower():
            n = str(n)
            signal_id.append('_'.join(n.split('Wh_hbb_')[1].split('_')[0:2]))

# %%
unique_name = np.unique(signal_id)

# %%
syst = ['JET_JER_EffectiveNP_1',
'JET_JER_EffectiveNP_2',
'JET_JER_EffectiveNP_3',
'JET_JER_EffectiveNP_4',
'JET_JER_EffectiveNP_5',
'JET_JER_EffectiveNP_6',
'JET_JER_EffectiveNP_7',
'JET_JER_EffectiveNP_8',
'JET_JER_EffectiveNP_9',
'JET_JER_EffectiveNP_10',
'JET_JER_EffectiveNP_11',
'JET_JER_EffectiveNP_12restTerm',
'JET_JER_DataVsMC',
'JET_BJES_Response',
'JET_EffectiveNP_Mixed1',
'JET_EffectiveNP_Mixed2',
'JET_EffectiveNP_Mixed3',
'JET_EffectiveNP_Detector1',
'JET_EffectiveNP_Detector2',
'JET_EffectiveNP_Modelling1',
'JET_EffectiveNP_Modelling2',
'JET_EffectiveNP_Modelling3',
'JET_EffectiveNP_Modelling4',
'JET_EffectiveNP_Statistical1',
'JET_EffectiveNP_Statistical2',
'JET_EffectiveNP_Statistical3',
'JET_EffectiveNP_Statistical4',
'JET_EffectiveNP_Statistical5',
'JET_EffectiveNP_Statistical6',
'JET_EtaIntercalibration_Modelling',
'JET_EtaIntercalibration_NonClosure_highE',
'JET_EtaIntercalibration_NonClosure_negEta',
'JET_EtaIntercalibration_NonClosure_posEta',
'JET_EtaIntercalibration_TotalStat',
'JET_Flavor_Composition',
'JET_Flavor_Response',
'JET_Pileup_OffsetMu',
'JET_Pileup_OffsetNPV',
'JET_Pileup_PtTerm',
'JET_Pileup_RhoTopology',
'JET_PunchThrough_MC16',
'JET_SingleParticle_HighPt',
'EG_RESOLUTION_ALL',
'EG_SCALE_ALL',
'EG_SCALE_AF2',
'EL_EFF_ID_TOTAL_1NPCOR_PLUS_UNCOR',
'EL_EFF_Reco_TOTAL_1NPCOR_PLUS_UNCOR',
'EL_EFF_Iso_TOTAL_1NPCOR_PLUS_UNCOR',
'MUON_ID',
'MUON_MS',
'MUON_SCALE',
'MUON_SAGITTA_RHO',
'MUON_SAGITTA_RESBIAS',
'MUON_EFF_RECO_STAT',
'MUON_EFF_RECO_SYS',
'MUON_EFF_RECO_STAT_LOWPT',
'MUON_EFF_RECO_SYS_LOWPT',
'MUON_EFF_ISO_STAT',
'MUON_EFF_ISO_SYS',
'MUON_EFF_BADMUON_STAT',
'MUON_EFF_BADMUON_SYS',
'MUON_EFF_TTVA_STAT',
'MUON_EFF_TTVA_SYS',
'FT_EFF_B_systematics',
'FT_EFF_C_systematics',
'FT_EFF_Light_systematics',
'FT_EFF_extrapolation',
'FT_EFF_extrapolation_from_charm',
'MET_SoftTrk_Scale',
'MET_SoftTrk_ResoPara',
'MET_SoftTrk_ResoPerp',
'jvtWeightJET_JvtEfficiency',
'pileupWeight']

# %%
signal_dict = {}

for n in unique_name:
    for names in root.keys():
        if n in str(names):
            if 'nosys' not in str(names).lower():
                if str(names).lower().split(';')[0].endswith('up'):
                    if ('_'.join(str(names).split('_')[5:])).split('__')[0] in syst:
                        try:
                            signal_dict[n].append(str(names).split(";")[0].split("'")[1])
                        except:
                            signal_dict[n] = [str(names).split(";")[0].split("'")[1]]

# %%
# for k in signal_dict.keys():
#     print(len(signal_dict[k]))

# %%
columns = ['met', 'mt', 'mbb', 'mct2',
        'mlb1', 'nJet30', 'lep1Pt', 'nBJet30_MV2c10',
           'genWeight','eventWeight', 'pileupWeight','leptonWeight','bTagWeight','jvtWeight',
        'trigMatch_metTrig', 'nLep_signal']

# %%
entrysteps=3000000
tot = 0
additional_cuts = True

for folder in unique_name:
    dir = numpy_sig_syst_up + '{}'.format(folder)
    if os.path.exists(dir):
        shutil.rmtree(dir)
        os.makedirs(dir)
    else:
        os.makedirs(dir)

    for name in signal_dict[folder]:

        events = uproot.open(data_folder)[name]
        array = events.lazyarray('met')

        print('lunghezza array', len(array))
        file_split = len(array)//entrysteps
        start_name_file = 0
        entrystart = start_name_file*entrysteps

        print(name)

        batches = events.iterate(columns, entrystart=entrystart,
                               entrysteps=entrysteps, 
                                   outputtype=pd.DataFrame)

        for ix in range(start_name_file, file_split+1):

            print(ix)    
            batch = next(batches)
            print('adding luminosity')
            batch['luminosity'] = 139000
            print(len(batch))

            batch = batch[batch['nLep_signal'].astype(int)==1]
            print('after signal {}'.format(len(batch)))

            batch = batch[batch['trigMatch_metTrig'].astype(int)==1]
            print('after trig {}'.format(len(batch)))

            batch = batch[((batch['nBJet30_MV2c10']>=1)&(batch['nBJet30_MV2c10']<4))]
            print('after bjet {}'.format(len(batch)))

#             batch = batch[((batch['met']>=220)&(batch['met']<=1000))]         
#             print('after met {}'.format(len(batch)))

#             batch = batch[((batch['mt']>=50)&(batch['mt']<=1000))]         
#             print('after mt {}'.format(len(batch)))
            
            batch = batch[batch['met']>=220]         
            print('after met {}'.format(len(batch)))

            batch = batch[batch['mt']>=50]         
            print('after mt {}'.format(len(batch)))

            batch = batch[((batch['mbb']>=100)&(batch['mbb']<=140))]  
            print('after mbb {}'.format(len(batch)))    
            
            batch = batch[batch['mct2']>100] 
            print('after mct2 {}'.format(len(batch)))
            
            if additional_cuts:

                print('cutting below 0 and above 1000')
                batch = batch[((batch['mct2']>=0)&(batch['mct2']<1000))]
                batch = batch[((batch['mt']>=0)&(batch['mt']<1000))]
                batch = batch[((batch['met']>=0)&(batch['met']<1000))]
                batch = batch[((batch['mlb1']>=0)&(batch['mlb1']<1000))]
                batch = batch[((batch['lep1Pt']>=0)&(batch['lep1Pt']<1000))]

            if len(batch) > 0:

                batch['weight'] = batch['genWeight']*batch['eventWeight']*batch['pileupWeight']*\
                                     batch['leptonWeight']*batch['bTagWeight']*batch['jvtWeight']*batch['luminosity']
#                 batch['weight'] = batch.apply(lambda row: row['genWeight']*row['eventWeight']*row['pileupWeight']*
#                                      row['leptonWeight']*row['bTagWeight']*row['jvtWeight']*row['luminosity'], axis=1)

                batch_fin = batch.iloc[:,:8]

                batch_fin['weight'] = batch['weight']

                batch_fin = batch_fin[['met', 'mt', 'mbb', 'mct2',
                'mlb1','lep1Pt', 'nJet30', 'nBJet30_MV2c10', 'weight']]

                tot = tot + len(batch)
                print('tot = {}'.format(tot))
                print("\x1b[31m\"saving {}_{}""\x1b[0m".format(name,ix))
                np.save(numpy_sig_syst_up + '{}/{}.npy'.format(folder,name), batch_fin.values)
# Out:
# lunghezza array 874
# C1N2_Wh_hbb_1000p0_0p0_EG_RESOLUTION_ALL__1up
# 0
# adding luminosity
# 874
# after signal 874
# after trig 866
# after bjet 866
# after met 866
# after mt 866
# after mbb 630
# after mct2 619
# cutting below 0 and above 1000
# tot = 530
# "saving C1N2_Wh_hbb_1000p0_0p0_EG_RESOLUTION_ALL__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_EG_SCALE_AF2__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 1059
# "saving C1N2_Wh_hbb_1000p0_0p0_EG_SCALE_AF2__1up_0
# lunghezza array 873
# C1N2_Wh_hbb_1000p0_0p0_EG_SCALE_ALL__1up
# 0
# adding luminosity
# 873
# after signal 873
# after trig 865
# after bjet 865
# after met 865
# after mt 865
# after mbb 630
# after mct2 619
# cutting below 0 and above 1000
# tot = 1589
# "saving C1N2_Wh_hbb_1000p0_0p0_EG_SCALE_ALL__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_BJES_Response__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 2118
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_BJES_Response__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Detector1__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 628
# after mct2 617
# cutting below 0 and above 1000
# tot = 2646
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Detector1__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Detector2__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 3175
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Detector2__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Mixed1__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 626
# after mct2 615
# cutting below 0 and above 1000
# tot = 3701
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Mixed1__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Mixed2__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 863
# after bjet 863
# after met 863
# after mt 863
# after mbb 631
# after mct2 620
# cutting below 0 and above 1000
# tot = 4232
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Mixed2__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Mixed3__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 4761
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Mixed3__1up_0
# lunghezza array 870
# C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Modelling1__1up
# 0
# adding luminosity
# 870
# after signal 870
# after trig 862
# after bjet 862
# after met 862
# after mt 862
# after mbb 621
# after mct2 611
# cutting below 0 and above 1000
# tot = 5286
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Modelling1__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Modelling2__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 628
# after mct2 617
# cutting below 0 and above 1000
# tot = 5813
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Modelling2__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Modelling3__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 630
# after mct2 619
# cutting below 0 and above 1000
# tot = 6343
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Modelling3__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Modelling4__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 6872
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Modelling4__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Statistical1__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 628
# after mct2 617
# cutting below 0 and above 1000
# tot = 7399
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Statistical1__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Statistical2__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 7927
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Statistical2__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Statistical3__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 630
# after mct2 619
# cutting below 0 and above 1000
# tot = 8457
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Statistical3__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Statistical4__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 8986
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Statistical4__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Statistical5__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 9515
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Statistical5__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Statistical6__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 10044
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EffectiveNP_Statistical6__1up_0
# lunghezza array 868
# C1N2_Wh_hbb_1000p0_0p0_JET_EtaIntercalibration_Modelling__1up
# 0
# adding luminosity
# 868
# after signal 868
# after trig 860
# after bjet 860
# after met 860
# after mt 860
# after mbb 625
# after mct2 615
# cutting below 0 and above 1000
# tot = 10570
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EtaIntercalibration_Modelling__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_EtaIntercalibration_NonClosure_highE__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 11099
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EtaIntercalibration_NonClosure_highE__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_EtaIntercalibration_NonClosure_negEta__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 11628
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EtaIntercalibration_NonClosure_negEta__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_EtaIntercalibration_NonClosure_posEta__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 12157
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EtaIntercalibration_NonClosure_posEta__1up_0
# lunghezza array 870
# C1N2_Wh_hbb_1000p0_0p0_JET_EtaIntercalibration_TotalStat__1up
# 0
# adding luminosity
# 870
# after signal 870
# after trig 862
# after bjet 862
# after met 862
# after mt 862
# after mbb 627
# after mct2 616
# cutting below 0 and above 1000
# tot = 12685
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_EtaIntercalibration_TotalStat__1up_0
# lunghezza array 866
# C1N2_Wh_hbb_1000p0_0p0_JET_Flavor_Composition__1up
# 0
# adding luminosity
# 866
# after signal 866
# after trig 858
# after bjet 858
# after met 858
# after mt 858
# after mbb 616
# after mct2 605
# cutting below 0 and above 1000
# tot = 13207
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_Flavor_Composition__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_0p0_JET_Flavor_Response__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 631
# after mct2 620
# cutting below 0 and above 1000
# tot = 13737
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_Flavor_Response__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_JER_DataVsMC__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 14266
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_JER_DataVsMC__1up_0
# lunghezza array 870
# C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_10__1up
# 0
# adding luminosity
# 870
# after signal 870
# after trig 862
# after bjet 862
# after met 862
# after mt 862
# after mbb 617
# after mct2 606
# cutting below 0 and above 1000
# tot = 14786
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_10__1up_0
# lunghezza array 870
# C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_11__1up
# 0
# adding luminosity
# 870
# after signal 870
# after trig 862
# after bjet 862
# after met 862
# after mt 862
# after mbb 622
# after mct2 611
# cutting below 0 and above 1000
# tot = 15311
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_11__1up_0
# lunghezza array 870
# C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_12restTerm__1up
# 0
# adding luminosity
# 870
# after signal 870
# after trig 862
# after bjet 862
# after met 862
# after mt 862
# after mbb 617
# after mct2 606
# cutting below 0 and above 1000
# tot = 15830
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_12restTerm__1up_0
# lunghezza array 867
# C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_1__1up
# 0
# adding luminosity
# 867
# after signal 867
# after trig 860
# after bjet 860
# after met 860
# after mt 860
# after mbb 612
# after mct2 603
# cutting below 0 and above 1000
# tot = 16350
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_1__1up_0
# lunghezza array 869
# C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_2__1up
# 0
# adding luminosity
# 869
# after signal 869
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 627
# after mct2 617
# cutting below 0 and above 1000
# tot = 16878
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_2__1up_0
# lunghezza array 868
# C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_3__1up
# 0
# adding luminosity
# 868
# after signal 868
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 615
# after mct2 604
# cutting below 0 and above 1000
# tot = 17398
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_3__1up_0
# lunghezza array 867
# C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_4__1up
# 0
# adding luminosity
# 867
# after signal 867
# after trig 860
# after bjet 860
# after met 860
# after mt 860
# after mbb 621
# after mct2 610
# cutting below 0 and above 1000
# tot = 17921
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_4__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_5__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 863
# after bjet 863
# after met 863
# after mt 863
# after mbb 626
# after mct2 615
# cutting below 0 and above 1000
# tot = 18447
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_5__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_6__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 621
# after mct2 609
# cutting below 0 and above 1000
# tot = 18970
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_6__1up_0
# lunghezza array 875
# C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_7__1up
# 0
# adding luminosity
# 875
# after signal 875
# after trig 867
# after bjet 867
# after met 867
# after mt 867
# after mbb 632
# after mct2 620
# cutting below 0 and above 1000
# tot = 19499
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_7__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_8__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 863
# after bjet 863
# after met 863
# after mt 863
# after mbb 622
# after mct2 611
# cutting below 0 and above 1000
# tot = 20021
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_8__1up_0
# lunghezza array 869
# C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_9__1up
# 0
# adding luminosity
# 869
# after signal 869
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 618
# after mct2 607
# cutting below 0 and above 1000
# tot = 20543
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_JER_EffectiveNP_9__1up_0
# lunghezza array 868
# C1N2_Wh_hbb_1000p0_0p0_JET_Pileup_OffsetMu__1up
# 0
# adding luminosity
# 868
# after signal 868
# after trig 860
# after bjet 860
# after met 860
# after mt 860
# after mbb 625
# after mct2 614
# cutting below 0 and above 1000
# tot = 21068
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_Pileup_OffsetMu__1up_0
# lunghezza array 867
# C1N2_Wh_hbb_1000p0_0p0_JET_Pileup_OffsetNPV__1up
# 0
# adding luminosity
# 867
# after signal 867
# after trig 859
# after bjet 859
# after met 859
# after mt 859
# after mbb 623
# after mct2 613
# cutting below 0 and above 1000
# tot = 21594
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_Pileup_OffsetNPV__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_Pileup_PtTerm__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 630
# after mct2 619
# cutting below 0 and above 1000
# tot = 22123
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_Pileup_PtTerm__1up_0
# lunghezza array 869
# C1N2_Wh_hbb_1000p0_0p0_JET_Pileup_RhoTopology__1up
# 0
# adding luminosity
# 869
# after signal 869
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 622
# after mct2 612
# cutting below 0 and above 1000
# tot = 22648
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_Pileup_RhoTopology__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_PunchThrough_MC16__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 23177
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_PunchThrough_MC16__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_JET_SingleParticle_HighPt__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 23706
# "saving C1N2_Wh_hbb_1000p0_0p0_JET_SingleParticle_HighPt__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_MUON_ID__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 24237
# "saving C1N2_Wh_hbb_1000p0_0p0_MUON_ID__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_MUON_MS__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 24765
# "saving C1N2_Wh_hbb_1000p0_0p0_MUON_MS__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_0p0_MUON_SAGITTA_RESBIAS__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 863
# after bjet 863
# after met 863
# after mt 863
# after mbb 630
# after mct2 618
# cutting below 0 and above 1000
# tot = 25293
# "saving C1N2_Wh_hbb_1000p0_0p0_MUON_SAGITTA_RESBIAS__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_MUON_SAGITTA_RHO__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 25822
# "saving C1N2_Wh_hbb_1000p0_0p0_MUON_SAGITTA_RHO__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_0p0_MUON_SCALE__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 629
# after mct2 618
# cutting below 0 and above 1000
# tot = 26351
# "saving C1N2_Wh_hbb_1000p0_0p0_MUON_SCALE__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_EG_RESOLUTION_ALL__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 26911
# "saving C1N2_Wh_hbb_1000p0_100p0_EG_RESOLUTION_ALL__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_EG_SCALE_AF2__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 27471
# "saving C1N2_Wh_hbb_1000p0_100p0_EG_SCALE_AF2__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_EG_SCALE_ALL__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 28031
# "saving C1N2_Wh_hbb_1000p0_100p0_EG_SCALE_ALL__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_BJES_Response__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 28591
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_BJES_Response__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Detector1__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 29151
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Detector1__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Detector2__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 29711
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Detector2__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Mixed1__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 656
# after mct2 644
# cutting below 0 and above 1000
# tot = 30268
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Mixed1__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Mixed2__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 647
# cutting below 0 and above 1000
# tot = 30828
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Mixed2__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Mixed3__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 31388
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Mixed3__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Modelling1__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 656
# after mct2 644
# cutting below 0 and above 1000
# tot = 31947
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Modelling1__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Modelling2__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 862
# after bjet 862
# after met 862
# after mt 862
# after mbb 657
# after mct2 646
# cutting below 0 and above 1000
# tot = 32507
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Modelling2__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Modelling3__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 659
# after mct2 647
# cutting below 0 and above 1000
# tot = 33068
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Modelling3__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Modelling4__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 33628
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Modelling4__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Statistical1__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 34188
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Statistical1__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Statistical2__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 862
# after bjet 862
# after met 862
# after mt 862
# after mbb 658
# after mct2 647
# cutting below 0 and above 1000
# tot = 34749
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Statistical2__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Statistical3__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 659
# after mct2 647
# cutting below 0 and above 1000
# tot = 35310
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Statistical3__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Statistical4__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 35870
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Statistical4__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Statistical5__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 36430
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Statistical5__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Statistical6__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 36990
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EffectiveNP_Statistical6__1up_0
# lunghezza array 870
# C1N2_Wh_hbb_1000p0_100p0_JET_EtaIntercalibration_Modelling__1up
# 0
# adding luminosity
# 870
# after signal 870
# after trig 860
# after bjet 860
# after met 860
# after mt 860
# after mbb 655
# after mct2 643
# cutting below 0 and above 1000
# tot = 37548
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EtaIntercalibration_Modelling__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_EtaIntercalibration_NonClosure_highE__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 38108
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EtaIntercalibration_NonClosure_highE__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_EtaIntercalibration_NonClosure_negEta__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 38668
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EtaIntercalibration_NonClosure_negEta__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_EtaIntercalibration_NonClosure_posEta__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 39228
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EtaIntercalibration_NonClosure_posEta__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_100p0_JET_EtaIntercalibration_TotalStat__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 862
# after bjet 862
# after met 862
# after mt 862
# after mbb 659
# after mct2 647
# cutting below 0 and above 1000
# tot = 39789
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_EtaIntercalibration_TotalStat__1up_0
# lunghezza array 868
# C1N2_Wh_hbb_1000p0_100p0_JET_Flavor_Composition__1up
# 0
# adding luminosity
# 868
# after signal 868
# after trig 858
# after bjet 858
# after met 858
# after mt 858
# after mbb 659
# after mct2 647
# cutting below 0 and above 1000
# tot = 40350
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_Flavor_Composition__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_Flavor_Response__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 656
# after mct2 645
# cutting below 0 and above 1000
# tot = 40910
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_Flavor_Response__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_JER_DataVsMC__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 41470
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_JER_DataVsMC__1up_0
# lunghezza array 876
# C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_10__1up
# 0
# adding luminosity
# 876
# after signal 876
# after trig 866
# after bjet 866
# after met 866
# after mt 866
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 42032
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_10__1up_0
# lunghezza array 877
# C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_11__1up
# 0
# adding luminosity
# 877
# after signal 877
# after trig 867
# after bjet 867
# after met 867
# after mt 867
# after mbb 661
# after mct2 649
# cutting below 0 and above 1000
# tot = 42594
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_11__1up_0
# lunghezza array 878
# C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_12restTerm__1up
# 0
# adding luminosity
# 878
# after signal 878
# after trig 868
# after bjet 868
# after met 868
# after mt 868
# after mbb 663
# after mct2 651
# cutting below 0 and above 1000
# tot = 43160
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_12restTerm__1up_0
# lunghezza array 874
# C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_1__1up
# 0
# adding luminosity
# 874
# after signal 874
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 650
# after mct2 637
# cutting below 0 and above 1000
# tot = 43714
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_1__1up_0
# lunghezza array 868
# C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_2__1up
# 0
# adding luminosity
# 868
# after signal 868
# after trig 858
# after bjet 858
# after met 858
# after mt 858
# after mbb 655
# after mct2 643
# cutting below 0 and above 1000
# tot = 44272
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_2__1up_0
# lunghezza array 874
# C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_3__1up
# 0
# adding luminosity
# 874
# after signal 874
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 652
# after mct2 641
# cutting below 0 and above 1000
# tot = 44829
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_3__1up_0
# lunghezza array 876
# C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_4__1up
# 0
# adding luminosity
# 876
# after signal 876
# after trig 866
# after bjet 866
# after met 866
# after mt 866
# after mbb 660
# after mct2 648
# cutting below 0 and above 1000
# tot = 45392
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_4__1up_0
# lunghezza array 874
# C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_5__1up
# 0
# adding luminosity
# 874
# after signal 874
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 45954
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_5__1up_0
# lunghezza array 873
# C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_6__1up
# 0
# adding luminosity
# 873
# after signal 873
# after trig 863
# after bjet 863
# after met 863
# after mt 863
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 46515
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_6__1up_0
# lunghezza array 875
# C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_7__1up
# 0
# adding luminosity
# 875
# after signal 875
# after trig 865
# after bjet 865
# after met 865
# after mt 865
# after mbb 661
# after mct2 649
# cutting below 0 and above 1000
# tot = 47077
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_7__1up_0
# lunghezza array 874
# C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_8__1up
# 0
# adding luminosity
# 874
# after signal 874
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 47639
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_8__1up_0
# lunghezza array 874
# C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_9__1up
# 0
# adding luminosity
# 874
# after signal 874
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 659
# after mct2 647
# cutting below 0 and above 1000
# tot = 48200
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_JER_EffectiveNP_9__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_100p0_JET_Pileup_OffsetMu__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 862
# after bjet 862
# after met 862
# after mt 862
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 48760
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_Pileup_OffsetMu__1up_0
# lunghezza array 873
# C1N2_Wh_hbb_1000p0_100p0_JET_Pileup_OffsetNPV__1up
# 0
# adding luminosity
# 873
# after signal 873
# after trig 863
# after bjet 863
# after met 863
# after mt 863
# after mbb 656
# after mct2 644
# cutting below 0 and above 1000
# tot = 49317
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_Pileup_OffsetNPV__1up_0
# lunghezza array 873
# C1N2_Wh_hbb_1000p0_100p0_JET_Pileup_PtTerm__1up
# 0
# adding luminosity
# 873
# after signal 873
# after trig 863
# after bjet 863
# after met 863
# after mt 863
# after mbb 656
# after mct2 645
# cutting below 0 and above 1000
# tot = 49876
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_Pileup_PtTerm__1up_0
# lunghezza array 869
# C1N2_Wh_hbb_1000p0_100p0_JET_Pileup_RhoTopology__1up
# 0
# adding luminosity
# 869
# after signal 869
# after trig 859
# after bjet 859
# after met 859
# after mt 859
# after mbb 655
# after mct2 643
# cutting below 0 and above 1000
# tot = 50434
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_Pileup_RhoTopology__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_PunchThrough_MC16__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 659
# after mct2 647
# cutting below 0 and above 1000
# tot = 50995
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_PunchThrough_MC16__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_JET_SingleParticle_HighPt__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 51555
# "saving C1N2_Wh_hbb_1000p0_100p0_JET_SingleParticle_HighPt__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_MUON_ID__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 52114
# "saving C1N2_Wh_hbb_1000p0_100p0_MUON_ID__1up_0
# lunghezza array 872
# C1N2_Wh_hbb_1000p0_100p0_MUON_MS__1up
# 0
# adding luminosity
# 872
# after signal 872
# after trig 862
# after bjet 862
# after met 862
# after mt 862
# after mbb 659
# after mct2 647
# cutting below 0 and above 1000
# tot = 52674
# "saving C1N2_Wh_hbb_1000p0_100p0_MUON_MS__1up_0
# lunghezza array 874
# C1N2_Wh_hbb_1000p0_100p0_MUON_SAGITTA_RESBIAS__1up
# 0
# adding luminosity
# 874
# after signal 874
# after trig 864
# after bjet 864
# after met 864
# after mt 864
# after mbb 660
# after mct2 646
# cutting below 0 and above 1000
# tot = 53236
# "saving C1N2_Wh_hbb_1000p0_100p0_MUON_SAGITTA_RESBIAS__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_MUON_SAGITTA_RHO__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 53796
# "saving C1N2_Wh_hbb_1000p0_100p0_MUON_SAGITTA_RHO__1up_0
# lunghezza array 871
# C1N2_Wh_hbb_1000p0_100p0_MUON_SCALE__1up
# 0
# adding luminosity
# 871
# after signal 871
# after trig 861
# after bjet 861
# after met 861
# after mt 861
# after mbb 658
# after mct2 646
# cutting below 0 and above 1000
# tot = 54356
# "saving C1N2_Wh_hbb_1000p0_100p0_MUON_SCALE__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_EG_RESOLUTION_ALL__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 54897
# "saving C1N2_Wh_hbb_1000p0_150p0_EG_RESOLUTION_ALL__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_EG_SCALE_AF2__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 55439
# "saving C1N2_Wh_hbb_1000p0_150p0_EG_SCALE_AF2__1up_0
# lunghezza array 853
# C1N2_Wh_hbb_1000p0_150p0_EG_SCALE_ALL__1up
# 0
# adding luminosity
# 853
# after signal 853
# after trig 848
# after bjet 848
# after met 848
# after mt 848
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 55980
# "saving C1N2_Wh_hbb_1000p0_150p0_EG_SCALE_ALL__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_BJES_Response__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 56522
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_BJES_Response__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Detector1__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 57064
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Detector1__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Detector2__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 57606
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Detector2__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Mixed1__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 648
# after mct2 637
# cutting below 0 and above 1000
# tot = 58149
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Mixed1__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Mixed2__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 643
# after mct2 633
# cutting below 0 and above 1000
# tot = 58690
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Mixed2__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Mixed3__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 59232
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Mixed3__1up_0
# lunghezza array 850
# C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Modelling1__1up
# 0
# adding luminosity
# 850
# after signal 850
# after trig 845
# after bjet 845
# after met 845
# after mt 845
# after mbb 648
# after mct2 636
# cutting below 0 and above 1000
# tot = 59774
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Modelling1__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Modelling2__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 645
# after mct2 635
# cutting below 0 and above 1000
# tot = 60315
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Modelling2__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Modelling3__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 643
# after mct2 633
# cutting below 0 and above 1000
# tot = 60856
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Modelling3__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Modelling4__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 61398
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Modelling4__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Statistical1__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 643
# after mct2 633
# cutting below 0 and above 1000
# tot = 61939
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Statistical1__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Statistical2__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 62481
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Statistical2__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Statistical3__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 643
# after mct2 633
# cutting below 0 and above 1000
# tot = 63022
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Statistical3__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Statistical4__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 63564
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Statistical4__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Statistical5__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 64106
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Statistical5__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Statistical6__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 64648
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EffectiveNP_Statistical6__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EtaIntercalibration_Modelling__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 646
# after mct2 635
# cutting below 0 and above 1000
# tot = 65191
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EtaIntercalibration_Modelling__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EtaIntercalibration_NonClosure_highE__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 65733
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EtaIntercalibration_NonClosure_highE__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EtaIntercalibration_NonClosure_negEta__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 66275
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EtaIntercalibration_NonClosure_negEta__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EtaIntercalibration_NonClosure_posEta__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 66817
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EtaIntercalibration_NonClosure_posEta__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_EtaIntercalibration_TotalStat__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 645
# after mct2 634
# cutting below 0 and above 1000
# tot = 67359
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_EtaIntercalibration_TotalStat__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_Flavor_Composition__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 651
# after mct2 638
# cutting below 0 and above 1000
# tot = 67904
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_Flavor_Composition__1up_0
# lunghezza array 855
# C1N2_Wh_hbb_1000p0_150p0_JET_Flavor_Response__1up
# 0
# adding luminosity
# 855
# after signal 855
# after trig 850
# after bjet 850
# after met 850
# after mt 850
# after mbb 644
# after mct2 635
# cutting below 0 and above 1000
# tot = 68447
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_Flavor_Response__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_JER_DataVsMC__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 68989
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_JER_DataVsMC__1up_0
# lunghezza array 853
# C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_10__1up
# 0
# adding luminosity
# 853
# after signal 853
# after trig 848
# after bjet 848
# after met 848
# after mt 848
# after mbb 642
# after mct2 630
# cutting below 0 and above 1000
# tot = 69528
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_10__1up_0
# lunghezza array 853
# C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_11__1up
# 0
# adding luminosity
# 853
# after signal 853
# after trig 848
# after bjet 848
# after met 848
# after mt 848
# after mbb 645
# after mct2 633
# cutting below 0 and above 1000
# tot = 70070
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_11__1up_0
# lunghezza array 853
# C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_12restTerm__1up
# 0
# adding luminosity
# 853
# after signal 853
# after trig 848
# after bjet 848
# after met 848
# after mt 848
# after mbb 644
# after mct2 633
# cutting below 0 and above 1000
# tot = 70611
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_12restTerm__1up_0
# lunghezza array 844
# C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_1__1up
# 0
# adding luminosity
# 844
# after signal 844
# after trig 839
# after bjet 839
# after met 839
# after mt 839
# after mbb 627
# after mct2 616
# cutting below 0 and above 1000
# tot = 71135
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_1__1up_0
# lunghezza array 850
# C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_2__1up
# 0
# adding luminosity
# 850
# after signal 850
# after trig 845
# after bjet 845
# after met 845
# after mt 845
# after mbb 643
# after mct2 633
# cutting below 0 and above 1000
# tot = 71676
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_2__1up_0
# lunghezza array 844
# C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_3__1up
# 0
# adding luminosity
# 844
# after signal 844
# after trig 839
# after bjet 839
# after met 839
# after mt 839
# after mbb 634
# after mct2 621
# cutting below 0 and above 1000
# tot = 72211
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_3__1up_0
# lunghezza array 853
# C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_4__1up
# 0
# adding luminosity
# 853
# after signal 853
# after trig 848
# after bjet 848
# after met 848
# after mt 848
# after mbb 643
# after mct2 633
# cutting below 0 and above 1000
# tot = 72751
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_4__1up_0
# lunghezza array 851
# C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_5__1up
# 0
# adding luminosity
# 851
# after signal 851
# after trig 846
# after bjet 846
# after met 846
# after mt 846
# after mbb 643
# after mct2 631
# cutting below 0 and above 1000
# tot = 73290
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_5__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_6__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 642
# after mct2 632
# cutting below 0 and above 1000
# tot = 73831
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_6__1up_0
# lunghezza array 851
# C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_7__1up
# 0
# adding luminosity
# 851
# after signal 851
# after trig 846
# after bjet 846
# after met 846
# after mt 846
# after mbb 644
# after mct2 633
# cutting below 0 and above 1000
# tot = 74371
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_7__1up_0
# lunghezza array 853
# C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_8__1up
# 0
# adding luminosity
# 853
# after signal 853
# after trig 848
# after bjet 848
# after met 848
# after mt 848
# after mbb 643
# after mct2 632
# cutting below 0 and above 1000
# tot = 74911
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_8__1up_0
# lunghezza array 849
# C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_9__1up
# 0
# adding luminosity
# 849
# after signal 849
# after trig 844
# after bjet 844
# after met 844
# after mt 844
# after mbb 640
# after mct2 629
# cutting below 0 and above 1000
# tot = 75449
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_JER_EffectiveNP_9__1up_0
# lunghezza array 851
# C1N2_Wh_hbb_1000p0_150p0_JET_Pileup_OffsetMu__1up
# 0
# adding luminosity
# 851
# after signal 851
# after trig 846
# after bjet 846
# after met 846
# after mt 846
# after mbb 644
# after mct2 635
# cutting below 0 and above 1000
# tot = 75992
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_Pileup_OffsetMu__1up_0
# lunghezza array 851
# C1N2_Wh_hbb_1000p0_150p0_JET_Pileup_OffsetNPV__1up
# 0
# adding luminosity
# 851
# after signal 851
# after trig 846
# after bjet 846
# after met 846
# after mt 846
# after mbb 643
# after mct2 634
# cutting below 0 and above 1000
# tot = 76534
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_Pileup_OffsetNPV__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_Pileup_PtTerm__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 641
# after mct2 631
# cutting below 0 and above 1000
# tot = 77073
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_Pileup_PtTerm__1up_0
# lunghezza array 850
# C1N2_Wh_hbb_1000p0_150p0_JET_Pileup_RhoTopology__1up
# 0
# adding luminosity
# 850
# after signal 850
# after trig 845
# after bjet 845
# after met 845
# after mt 845
# after mbb 648
# after mct2 636
# cutting below 0 and above 1000
# tot = 77616
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_Pileup_RhoTopology__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_PunchThrough_MC16__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 78158
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_PunchThrough_MC16__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_JET_SingleParticle_HighPt__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 78700
# "saving C1N2_Wh_hbb_1000p0_150p0_JET_SingleParticle_HighPt__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_MUON_ID__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 79241
# "saving C1N2_Wh_hbb_1000p0_150p0_MUON_ID__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_MUON_MS__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 633
# cutting below 0 and above 1000
# tot = 79783
# "saving C1N2_Wh_hbb_1000p0_150p0_MUON_MS__1up_0
# lunghezza array 851
# C1N2_Wh_hbb_1000p0_150p0_MUON_SAGITTA_RESBIAS__1up
# 0
# adding luminosity
# 851
# after signal 851
# after trig 846
# after bjet 846
# after met 846
# after mt 846
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 80324
# "saving C1N2_Wh_hbb_1000p0_150p0_MUON_SAGITTA_RESBIAS__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_MUON_SAGITTA_RHO__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 80866
# "saving C1N2_Wh_hbb_1000p0_150p0_MUON_SAGITTA_RHO__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_1000p0_150p0_MUON_SCALE__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 644
# after mct2 634
# cutting below 0 and above 1000
# tot = 81408
# "saving C1N2_Wh_hbb_1000p0_150p0_MUON_SCALE__1up_0
# lunghezza array 839
# C1N2_Wh_hbb_1000p0_200p0_EG_RESOLUTION_ALL__1up
# 0
# adding luminosity
# 839
# after signal 839
# after trig 831
# after bjet 831
# after met 831
# after mt 831
# after mbb 619
# after mct2 609
# cutting below 0 and above 1000
# tot = 81943
# "saving C1N2_Wh_hbb_1000p0_200p0_EG_RESOLUTION_ALL__1up_0
# lunghezza array 839
# C1N2_Wh_hbb_1000p0_200p0_EG_SCALE_AF2__1up
# 0
# adding luminosity
# 839
# after signal 839
# after trig 831
# after bjet 831
# after met 831
# after mt 831
# after mbb 619
# after mct2 609
# cutting below 0 and above 1000
# tot = 82478
# "saving C1N2_Wh_hbb_1000p0_200p0_EG_SCALE_AF2__1up_0
# lunghezza array 839
# C1N2_Wh_hbb_1000p0_200p0_EG_SCALE_ALL__1up
# 0
# adding luminosity
# 839
# after signal 839
# after trig 831
# after bjet 831
# after met 831
# after mt 831
# after mbb 619
# after mct2 609
# cutting below 0 and above 1000
# tot = 83012
# "saving C1N2_Wh_hbb_1000p0_200p0_EG_SCALE_ALL__1up_0
# lunghezza array 839
# C1N2_Wh_hbb_1000p0_200p0_JET_BJES_Response__1up
# 0
# adding luminosity
# 839
# after signal 839
# after trig 831
# after bjet 831
# after met 831
# after mt 831
# after mbb 619
# after mct2 609
# cutting below 0 and above 1000
# tot = 83547
# "saving C1N2_Wh_hbb_1000p0_200p0_JET_BJES_Response__1up_0
# lunghezza array 840
# C1N2_Wh_hbb_1000p0_200p0_JET_EffectiveNP_Detector1__1up
# 0
# adding luminosity
# 840
# after signal 840
# after trig 832
# after bjet 832
# after met 832
# after mt 832
# after mbb 620
# after mct2 610
# cutting below 0 and above 1000
# tot = 84083
# "saving C1N2_Wh_hbb_1000p0_200p0_JET_EffectiveNP_Detector1__1up_0
# lunghezza array 839
# C1N2_Wh_hbb_1000p0_200p0_JET_EffectiveNP_Detector2__1up
# 0
# adding luminosity
# 839
# after signal 839
# after trig 831
# after bjet 831
# after met 831
# after mt 831
# after mbb 619
# after mct2 609
# cutting below 0 and above 1000
# tot = 84618
# "saving C1N2_Wh_hbb_1000p0_200p0_JET_EffectiveNP_Detector2__1up_0
# lunghezza array 839
# C1N2_Wh_hbb_1000p0_200p0_JET_EffectiveNP_Mixed1__1up
# 0
# adding luminosity
# 839
# after signal 839
# after trig 831
# after bjet 831
# after met 831
# after mt 831
# after mbb 620
# after mct2 610
# cutting below 0 and above 1000
# tot = 85153
# ...
# after mt 762
# after mbb 565
# after mct2 546
# cutting below 0 and above 1000
# tot = 2959535
# "saving C1N2_Wh_hbb_900p0_400p0_MUON_SAGITTA_RESBIAS__1up_0
# lunghezza array 771
# C1N2_Wh_hbb_900p0_400p0_MUON_SAGITTA_RHO__1up
# 0
# adding luminosity
# 771
# after signal 771
# after trig 763
# after bjet 763
# after met 763
# after mt 763
# after mbb 567
# after mct2 548
# cutting below 0 and above 1000
# tot = 2960062
# "saving C1N2_Wh_hbb_900p0_400p0_MUON_SAGITTA_RHO__1up_0
# lunghezza array 771
# C1N2_Wh_hbb_900p0_400p0_MUON_SCALE__1up
# 0
# adding luminosity
# 771
# after signal 771
# after trig 763
# after bjet 763
# after met 763
# after mt 763
# after mbb 567
# after mct2 548
# cutting below 0 and above 1000
# tot = 2960589
# "saving C1N2_Wh_hbb_900p0_400p0_MUON_SCALE__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_EG_RESOLUTION_ALL__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2961165
# "saving C1N2_Wh_hbb_900p0_50p0_EG_RESOLUTION_ALL__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_EG_SCALE_AF2__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2961741
# "saving C1N2_Wh_hbb_900p0_50p0_EG_SCALE_AF2__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_EG_SCALE_ALL__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2962316
# "saving C1N2_Wh_hbb_900p0_50p0_EG_SCALE_ALL__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_BJES_Response__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2962892
# "saving C1N2_Wh_hbb_900p0_50p0_JET_BJES_Response__1up_0
# lunghezza array 859
# C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Detector1__1up
# 0
# adding luminosity
# 859
# after signal 859
# after trig 850
# after bjet 850
# after met 850
# after mt 850
# after mbb 648
# after mct2 630
# cutting below 0 and above 1000
# tot = 2963467
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Detector1__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Detector2__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2964043
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Detector2__1up_0
# lunghezza array 861
# C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Mixed1__1up
# 0
# adding luminosity
# 861
# after signal 861
# after trig 852
# after bjet 852
# after met 852
# after mt 852
# after mbb 650
# after mct2 632
# cutting below 0 and above 1000
# tot = 2964619
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Mixed1__1up_0
# lunghezza array 859
# C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Mixed2__1up
# 0
# adding luminosity
# 859
# after signal 859
# after trig 850
# after bjet 850
# after met 850
# after mt 850
# after mbb 648
# after mct2 629
# cutting below 0 and above 1000
# tot = 2965193
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Mixed2__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Mixed3__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2965769
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Mixed3__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Modelling1__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 655
# after mct2 637
# cutting below 0 and above 1000
# tot = 2966350
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Modelling1__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Modelling2__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2966926
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Modelling2__1up_0
# lunghezza array 859
# C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Modelling3__1up
# 0
# adding luminosity
# 859
# after signal 859
# after trig 850
# after bjet 850
# after met 850
# after mt 850
# after mbb 649
# after mct2 630
# cutting below 0 and above 1000
# tot = 2967501
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Modelling3__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Modelling4__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2968077
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Modelling4__1up_0
# lunghezza array 859
# C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Statistical1__1up
# 0
# adding luminosity
# 859
# after signal 859
# after trig 850
# after bjet 850
# after met 850
# after mt 850
# after mbb 649
# after mct2 630
# cutting below 0 and above 1000
# tot = 2968652
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Statistical1__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Statistical2__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2969228
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Statistical2__1up_0
# lunghezza array 859
# C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Statistical3__1up
# 0
# adding luminosity
# 859
# after signal 859
# after trig 850
# after bjet 850
# after met 850
# after mt 850
# after mbb 649
# after mct2 630
# cutting below 0 and above 1000
# tot = 2969803
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Statistical3__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Statistical4__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2970379
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Statistical4__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Statistical5__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2970955
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Statistical5__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Statistical6__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2971531
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EffectiveNP_Statistical6__1up_0
# lunghezza array 857
# C1N2_Wh_hbb_900p0_50p0_JET_EtaIntercalibration_Modelling__1up
# 0
# adding luminosity
# 857
# after signal 857
# after trig 849
# after bjet 849
# after met 849
# after mt 849
# after mbb 649
# after mct2 631
# cutting below 0 and above 1000
# tot = 2972106
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EtaIntercalibration_Modelling__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_EtaIntercalibration_NonClosure_highE__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2972682
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EtaIntercalibration_NonClosure_highE__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_EtaIntercalibration_NonClosure_negEta__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2973258
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EtaIntercalibration_NonClosure_negEta__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_EtaIntercalibration_NonClosure_posEta__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2973834
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EtaIntercalibration_NonClosure_posEta__1up_0
# lunghezza array 857
# C1N2_Wh_hbb_900p0_50p0_JET_EtaIntercalibration_TotalStat__1up
# 0
# adding luminosity
# 857
# after signal 857
# after trig 848
# after bjet 848
# after met 848
# after mt 848
# after mbb 647
# after mct2 629
# cutting below 0 and above 1000
# tot = 2974408
# "saving C1N2_Wh_hbb_900p0_50p0_JET_EtaIntercalibration_TotalStat__1up_0
# lunghezza array 856
# C1N2_Wh_hbb_900p0_50p0_JET_Flavor_Composition__1up
# 0
# adding luminosity
# 856
# after signal 856
# after trig 848
# after bjet 848
# after met 848
# after mt 848
# after mbb 655
# after mct2 638
# cutting below 0 and above 1000
# tot = 2974988
# "saving C1N2_Wh_hbb_900p0_50p0_JET_Flavor_Composition__1up_0
# lunghezza array 858
# C1N2_Wh_hbb_900p0_50p0_JET_Flavor_Response__1up
# 0
# adding luminosity
# 858
# after signal 858
# after trig 849
# after bjet 849
# after met 849
# after mt 849
# after mbb 642
# after mct2 624
# cutting below 0 and above 1000
# tot = 2975557
# "saving C1N2_Wh_hbb_900p0_50p0_JET_Flavor_Response__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_JER_DataVsMC__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2976133
# "saving C1N2_Wh_hbb_900p0_50p0_JET_JER_DataVsMC__1up_0
# lunghezza array 858
# C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_10__1up
# 0
# adding luminosity
# 858
# after signal 858
# after trig 849
# after bjet 849
# after met 849
# after mt 849
# after mbb 646
# after mct2 629
# cutting below 0 and above 1000
# tot = 2976705
# "saving C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_10__1up_0
# lunghezza array 861
# C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_11__1up
# 0
# adding luminosity
# 861
# after signal 861
# after trig 852
# after bjet 852
# after met 852
# after mt 852
# after mbb 652
# after mct2 634
# cutting below 0 and above 1000
# tot = 2977284
# "saving C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_11__1up_0
# lunghezza array 856
# C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_12restTerm__1up
# 0
# adding luminosity
# 856
# after signal 856
# after trig 847
# after bjet 847
# after met 847
# after mt 847
# after mbb 646
# after mct2 629
# cutting below 0 and above 1000
# tot = 2977856
# "saving C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_12restTerm__1up_0
# lunghezza array 854
# C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_1__1up
# 0
# adding luminosity
# 854
# after signal 854
# after trig 845
# after bjet 845
# after met 845
# after mt 845
# after mbb 643
# after mct2 627
# cutting below 0 and above 1000
# tot = 2978423
# "saving C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_1__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_2__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2978999
# "saving C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_2__1up_0
# lunghezza array 852
# C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_3__1up
# 0
# adding luminosity
# 852
# after signal 852
# after trig 843
# after bjet 843
# after met 843
# after mt 843
# after mbb 644
# after mct2 628
# cutting below 0 and above 1000
# tot = 2979571
# "saving C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_3__1up_0
# lunghezza array 857
# C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_4__1up
# 0
# adding luminosity
# 857
# after signal 857
# after trig 848
# after bjet 848
# after met 848
# after mt 848
# after mbb 650
# after mct2 633
# cutting below 0 and above 1000
# tot = 2980148
# "saving C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_4__1up_0
# lunghezza array 857
# C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_5__1up
# 0
# adding luminosity
# 857
# after signal 857
# after trig 848
# after bjet 848
# after met 848
# after mt 848
# after mbb 647
# after mct2 628
# cutting below 0 and above 1000
# tot = 2980720
# "saving C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_5__1up_0
# lunghezza array 858
# C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_6__1up
# 0
# adding luminosity
# 858
# after signal 858
# after trig 849
# after bjet 849
# after met 849
# after mt 849
# after mbb 648
# after mct2 631
# cutting below 0 and above 1000
# tot = 2981295
# "saving C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_6__1up_0
# lunghezza array 857
# C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_7__1up
# 0
# adding luminosity
# 857
# after signal 857
# after trig 848
# after bjet 848
# after met 848
# after mt 848
# after mbb 647
# after mct2 628
# cutting below 0 and above 1000
# tot = 2981868
# "saving C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_7__1up_0
# lunghezza array 857
# C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_8__1up
# 0
# adding luminosity
# 857
# after signal 857
# after trig 848
# after bjet 848
# after met 848
# after mt 848
# after mbb 645
# after mct2 628
# cutting below 0 and above 1000
# tot = 2982439
# "saving C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_8__1up_0
# lunghezza array 855
# C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_9__1up
# 0
# adding luminosity
# 855
# after signal 855
# after trig 846
# after bjet 846
# after met 846
# after mt 846
# after mbb 649
# after mct2 632
# cutting below 0 and above 1000
# tot = 2983015
# "saving C1N2_Wh_hbb_900p0_50p0_JET_JER_EffectiveNP_9__1up_0
# lunghezza array 858
# C1N2_Wh_hbb_900p0_50p0_JET_Pileup_OffsetMu__1up
# 0
# adding luminosity
# 858
# after signal 858
# after trig 850
# after bjet 850
# after met 850
# after mt 850
# after mbb 649
# after mct2 631
# cutting below 0 and above 1000
# tot = 2983591
# "saving C1N2_Wh_hbb_900p0_50p0_JET_Pileup_OffsetMu__1up_0
# lunghezza array 859
# C1N2_Wh_hbb_900p0_50p0_JET_Pileup_OffsetNPV__1up
# 0
# adding luminosity
# 859
# after signal 859
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 651
# after mct2 633
# cutting below 0 and above 1000
# tot = 2984168
# "saving C1N2_Wh_hbb_900p0_50p0_JET_Pileup_OffsetNPV__1up_0
# lunghezza array 861
# C1N2_Wh_hbb_900p0_50p0_JET_Pileup_PtTerm__1up
# 0
# adding luminosity
# 861
# after signal 861
# after trig 852
# after bjet 852
# after met 852
# after mt 852
# after mbb 648
# after mct2 631
# cutting below 0 and above 1000
# tot = 2984743
# "saving C1N2_Wh_hbb_900p0_50p0_JET_Pileup_PtTerm__1up_0
# lunghezza array 859
# C1N2_Wh_hbb_900p0_50p0_JET_Pileup_RhoTopology__1up
# 0
# adding luminosity
# 859
# after signal 859
# after trig 850
# after bjet 850
# after met 850
# after mt 850
# after mbb 651
# after mct2 633
# cutting below 0 and above 1000
# tot = 2985320
# "saving C1N2_Wh_hbb_900p0_50p0_JET_Pileup_RhoTopology__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_PunchThrough_MC16__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 649
# after mct2 630
# cutting below 0 and above 1000
# tot = 2985895
# "saving C1N2_Wh_hbb_900p0_50p0_JET_PunchThrough_MC16__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_JET_SingleParticle_HighPt__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2986471
# "saving C1N2_Wh_hbb_900p0_50p0_JET_SingleParticle_HighPt__1up_0
# lunghezza array 863
# C1N2_Wh_hbb_900p0_50p0_MUON_ID__1up
# 0
# adding luminosity
# 863
# after signal 863
# after trig 854
# after bjet 854
# after met 854
# after mt 854
# after mbb 652
# after mct2 632
# cutting below 0 and above 1000
# tot = 2987047
# "saving C1N2_Wh_hbb_900p0_50p0_MUON_ID__1up_0
# lunghezza array 861
# C1N2_Wh_hbb_900p0_50p0_MUON_MS__1up
# 0
# adding luminosity
# 861
# after signal 861
# after trig 852
# after bjet 852
# after met 852
# after mt 852
# after mbb 651
# after mct2 632
# cutting below 0 and above 1000
# tot = 2987623
# "saving C1N2_Wh_hbb_900p0_50p0_MUON_MS__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_MUON_SAGITTA_RESBIAS__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 651
# after mct2 634
# cutting below 0 and above 1000
# tot = 2988204
# "saving C1N2_Wh_hbb_900p0_50p0_MUON_SAGITTA_RESBIAS__1up_0
# lunghezza array 860
# C1N2_Wh_hbb_900p0_50p0_MUON_SAGITTA_RHO__1up
# 0
# adding luminosity
# 860
# after signal 860
# after trig 851
# after bjet 851
# after met 851
# after mt 851
# after mbb 650
# after mct2 631
# cutting below 0 and above 1000
# tot = 2988780
# "saving C1N2_Wh_hbb_900p0_50p0_MUON_SAGITTA_RHO__1up_0
# lunghezza array 858
# C1N2_Wh_hbb_900p0_50p0_MUON_SCALE__1up
# 0
# adding luminosity
# 858
# after signal 858
# after trig 849
# after bjet 849
# after met 849
# after mt 849
# after mbb 649
# after mct2 630
# cutting below 0 and above 1000
# tot = 2989355
# "saving C1N2_Wh_hbb_900p0_50p0_MUON_SCALE__1up_0
